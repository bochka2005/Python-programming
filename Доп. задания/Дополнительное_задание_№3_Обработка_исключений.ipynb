# %% [markdown]
# <a href="https://colab.research.google.com/github/bochka2005/Python-programming/blob/main/%D0%94%D0%BE%D0%BF.%20%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F/%D0%94%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%963_%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D0%B8%D1%81%D0%BA%D0%BB%D1%8E%D1%87%D0%B5%D0%BD%D0%B8%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Дополнительное задание №3. Обработка исключений и работа с текстовыми файлами**

# %% [markdown]
# **БАЗА:**
#
# - **Обработка исключений** позволяет перехватывать и обрабатывать ошибки, возникающие при выполнении программы, предотвращая её аварийное завершение.
# - **Работа с файлами** - важный навык для чтения, записи и обработки текстовой информации в Python.
#
# ---

# %% [markdown]
# ## **I. Обработка исключений**

# %% [markdown]
# ### **Пункт №1. Обработка некорректного индекса (IndexError)**

# %% [markdown]
# Создайте список из нескольких элементов (например, [10, 20, 30]). Попросите пользователя ввести индекс элемента, который нужно вывести. Если пользователь введёт индекс, выходящий за границы списка, перехватите IndexError и сообщите об этом.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте список из минимум 5 элементов
# - Покажите содержимое списка перед работой
# - Протестируйте минимум 4 случая (корректный индекс, отрицательный, слишком большой, нечисловое значение)

# %%
my_list = [10, 20, 30, 40, 50]
print(f"Список: {my_list}")
print(f"Длина списка: {len(my_list)}")

test_cases = [2, -1, 10, "abc"]

for i in test_cases:
    print(f"\nЭлемент с индексом {i}:")
    try:
        print(f"Элемент: {my_list[i]}")
    except IndexError:
        print(f"Ошибка: индекс {i} вне диапазона!")
    except TypeError:
        print(f"Ошибка: '{i}' не является числом!")
# Out:
# Список: [10, 20, 30, 40, 50]
# Длина списка: 5
#
# Элемент с индексом 2:
# Элемент: 30
#
# Элемент с индексом -1:
# Элемент: 50
#
# Элемент с индексом 10:
# Ошибка: индекс 10 вне диапазона!
#
# Элемент с индексом abc:
# Ошибка: 'abc' не является числом!

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Обработка исключений в цикле**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя числа и добавляет их в список.
# - Если пользователь вводит некорректные данные, программа должна выводить сообщение об ошибке и продолжать работу.
# - Для выхода из программы пользователь должен ввести "стоп".
#
# **ОБЯЗАТЕЛЬНО:**
# - Покажите процесс ввода минимум 7 значений (включая ошибочные)
# - Выведите финальный список и статистику (сколько чисел введено успешно, сколько ошибок)

# %% [markdown]
# ```
# # Пример:
# # Введите число: 10
# # Введите число: текст (Ошибка: это не число)
# # Введите число: стоп
# # Итоговый список: [10]
# ```

# %%
nums = []
err = 0

print("Ввод чисел ('стоп' для выхода):")

while True:
    x = input("> ")
    if x == 'стоп':
        break
    try:
        nums.append(float(x))
    except:
        err += 1
        print("Ошибка!")

print(f"\nСписок: {nums}")
print(f"Успешно: {len(nums)}")
print(f"Ошибок: {err}")
# Out:
# Ввод чисел ('стоп' для выхода):
# > 10
# > текст
# Ошибка!
# > стоп
#
# Список: [10.0]
# Успешно: 1
# Ошибок: 1

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3**

# %% [markdown]
# Создайте функцию `get_list_element(lst, index)`, которая безопасно извлекает элемент списка по индексу с использованием блоков `try`, `except`, `else` и `finally`.
#
# Функция должна:
# - Обрабатывать выход за пределы списка
# - Обрабатывать некорректный тип индекса
# - Выводить сообщение о попытке доступа в блоке `finally`
#
# **ОБЯЗАТЕЛЬНО:**
# - Выведите результаты для минимум 4 различных случаев (успешный доступ, выход за границы, отрицательный индекс, нечисловой индекс)
# - Покажите, что блок `finally` выполняется всегда
#
# ```python
# # Пример использования:
# my_list = [1, 2, 3, 4, 5]
# get_list_element(my_list, 2)   # Вывод: "Элемент: 3", "Попытка доступа завершена"
# get_list_element(my_list, 10)  # Вывод: "Индекс вне диапазона", "Попытка доступа завершена"
# ```

# %%
def get_list_element(lst, index):
    try:
        element = lst[index]
    except IndexError:
        print(f"Ошибка: индекс {index} вне диапазона!")
    except TypeError:
        print(f"Ошибка: '{index}' не является числом!")
    else:
        print(f"Элемент: {element}")
    finally:
        print("Попытка доступа завершена\n")

my_list = [1, 2, 3, 4, 5]
print(f"Список: {my_list}")

get_list_element(my_list, 2)
get_list_element(my_list, 10)
get_list_element(my_list, -1)
get_list_element(my_list, "a")
# Out:
# Список: [1, 2, 3, 4, 5]
# Элемент: 3
# Попытка доступа завершена
#
# Ошибка: индекс 10 вне диапазона!
# Попытка доступа завершена
#
# Элемент: 5
# Попытка доступа завершена
#
# Ошибка: 'a' не является числом!
# Попытка доступа завершена

# %% [markdown]
# ---

# %% [markdown]
# ## **II. Работа с текстовыми файлами**

# %% [markdown]
# ### **Пункт №1. Запись в файл**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя строку и записывает её в файл output.txt в режиме дозаписи.
#
# **ОБЯЗАТЕЛЬНО:**
# - Запросите у пользователя минимум 3 строки
# - Покажите содержимое файла после записи

# %%
print("Введите 3 строки для записи в файл:")

for i in range(3):
    text = input(f"Строка {i+1}: ")
    with open('output.txt', 'a', encoding='utf-8') as f:
        f.write(f'\n{text}')

print("\nСодержимое файла:")
with open('output.txt', 'r', encoding='utf-8') as f:
    print(f.read())
# Out:
# Введите 3 строки для записи в файл:
# Строка 1: бим
# Строка 2: бам
# Строка 3: бом
#
# Содержимое файла:
# новое, а может старое
# бим
# бам
# бом

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Чтение из файла**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и выводит его содержимое на экран.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 5 строками текста
# - Покажите содержимое файла целиком
# - Обработайте случай отсутствующего файла

# %%
with open('output.txt', 'w') as f:
    f.write('''Строка 1
Строка 2
Строка 3
Строка 4
Строка 5''')

print("Содержимое файла:")
try:
    with open('output.txt') as f:
        print(f.read())
except FileNotFoundError:
    print("Файл не найден")

print("\nПопытка открыть несуществующий файл:")
try:
    with open('no_file.txt') as f:
        print(f.read())
except FileNotFoundError:
    print("Файл не найден")
# Out:
# Содержимое файла:
# Строка 1
# Строка 2
# Строка 3
# Строка 4
# Строка 5
#
# Попытка открыть несуществующий файл:
# Файл не найден

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3. Подсчет строк в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и подсчитывает количество строк в нём.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с известным количеством строк (минимум 10)
# - Покажите первые 3 строки файла
# - Выведите общее количество строк
# - Выведите количество непустых строк

# %%
with open('output.txt', 'w') as f:
    for i in range(1, 11):
        f.write(f'Строка номер {i}\n')

print("Первые 3 строки файла:")
with open('output.txt') as f:
    for i in range(3):
        print(f"Строка {i+1}: {f.readline().rstrip()}")

print("\nСодержимое всего файла:")
with open('output.txt') as f:
    content = f.read()
    print(content)

with open('output.txt') as f:
    all_lines = f.readlines()
    total_lines = len(all_lines)
    non_empty_lines = len([line for line in all_lines if line.strip() != ''])

print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Пустых строк: {total_lines - non_empty_lines}")
# Out:
# Первые 3 строки файла:
# Строка 1: Строка номер 1
# Строка 2: Строка номер 2
# Строка 3: Строка номер 3
#
# Содержимое всего файла:
# Строка номер 1
# Строка номер 2
# Строка номер 3
# Строка номер 4
# Строка номер 5
# Строка номер 6
# Строка номер 7
# Строка номер 8
# Строка номер 9
# Строка номер 10
#
# Всего строк: 10
# Непустых строк: 10
# Пустых строк: 0

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №4. Копирование содержимого файла**

# %% [markdown]
# Напишите программу, которая копирует содержимое файла input.txt в файл output.txt.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте исходный файл с тестовым содержимым (минимум 5 строк)
# - Покажите содержимое исходного файла
# - Выполните копирование
# - Покажите содержимое скопированного файла
# - Обработайте случай отсутствия исходного файла

# %%
with open('input.txt', 'w') as f:
    f.write('Строка 1\nСтрока 2\nСтрока 3\nСтрока 4\nСтрока 5')

print("Исходный файл:")
with open('input.txt') as f:
    print(f.read())

try:
    with open('input.txt') as src, open('output.txt', 'w') as dst:
        dst.write(src.read())
    print("\nСкопированный файл:")
    with open('output.txt') as f:
        print(f.read())
except FileNotFoundError:
    print("Файл не найден!")
# Out:
# Исходный файл:
# Строка 1
# Строка 2
# Строка 3
# Строка 4
# Строка 5
#
# Скопированный файл:
# Строка 1
# Строка 2
# Строка 3
# Строка 4
# Строка 5

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №5. Поиск слова в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и проверяет, содержится ли в нём слово, введённое пользователем.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 10 строками текста
# - Покажите содержимое файла
# - Протестируйте поиск минимум 5 различных слов
# - Выведите номера строк, где найдено слово
# - Покажите количество вхождений слова

# %%
with open('animals.txt', 'w', encoding='utf-8') as f:
    f.write('''Лев - царь зверей
Собака - лучший друг человека
Кошка - домашнее животное
Слон - большое животное
Обезьяна - умное животное
Тигр - опасное животное
Попугай - красивая птица
Дельфин - умное животное
Лошадь - сильное животное
Змея - длинное животное''')

print("Содержимое файла:")
with open('animals.txt', encoding='utf-8') as f:
    print(f.read())

word = input("\nВведите слово для поиска: ")

with open('animals.txt', encoding='utf-8') as f:
    lines = f.readlines()
    found = []
    total_count = 0

    for i, line in enumerate(lines, 1):
        count_in_line = line.lower().count(word.lower())
        if count_in_line > 0:
            found.append(i)
            total_count += count_in_line

    print(f"\nРезультаты поиска '{word}':")
    print(f"Всего вхождений: {total_count}")
    print(f"Строки: {found if found else 'не найдено'}")
# Out:
# Содержимое файла:
# Лев - царь зверей
# Собака - лучший друг человека
# Кошка - домашнее животное
# Слон - большое животное
# Обезьяна - умное животное
# Тигр - опасное животное
# Попугай - красивая птица
# Дельфин - умное животное
# Лошадь - сильное животное
# Змея - длинное животное
#
# Введите слово для поиска: животное
#
# Результаты поиска 'животное':
# Всего вхождений: 7
# Строки: [3, 4, 5, 6, 8, 9, 10]

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №6. Чтение файла с обработкой FileNotFoundError**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя имя файла и пытается открыть его. Если файла не существует, перехватите FileNotFoundError и выведите сообщение «Файл не найден!».
#
# **ОБЯЗАТЕЛЬНО:**
# - Протестируйте с существующим файлом
# - Протестируйте с несуществующим файлом
# - Покажите содержимое существующего файла

# %%
try:
    filename = input("Введите имя файла: ")
    with open(filename) as f:
        print(f.read())
except FileNotFoundError:
    print("Файл не найден!")
# Out:
# Введите имя файла: fsfs.txt
# Файл не найден!

# %%
try:
    filename = input("Введите имя файла: ")
    with open(filename) as f:
        print(f.read())
except FileNotFoundError:
    print("Файл не найден!")
# Out:
# Введите имя файла: animals.txt
# Лев - царь зверей
# Собака - лучший друг человека
# Кошка - домашнее животное
# Слон - большое животное
# Обезьяна - умное животное
# Тигр - опасное животное
# Попугай - красивая птица
# Дельфин - умное животное
# Лошадь - сильное животное
# Змея - длинное животное

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №7. Подсчет статистики файла**

# %% [markdown]
# Напишите функцию `file_statistics(filename)`, которая читает текстовый файл и возвращает словарь со статистикой:
# - Количество строк
# - Количество слов
# - Количество символов (с пробелами и без)
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с минимум 5 строками текста
# - Выведите содержимое файла ДО обработки
# - Выведите полученную статистику
# - Обработайте случай несуществующего файла
#
# ```python
# # Создание тестового файла
# test_content = """Первая строка текста
# Вторая строка с большим количеством слов
# Третья строка
# Четвертая строка для теста
# Пятая и последняя строка"""
#
# # Сохраните в файл и продемонстрируйте работу
# ```

# %%
def file_statistics(filename):
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            content = f.read()

        lines = content.split('\n')
        words = content.split()

        return {
            'lines': len(lines),
            'words': len(words),
            'chars_with_spaces': len(content),
            'chars_without_spaces': len(content.replace(' ', ''))
        }
    except FileNotFoundError:
        return "Файл не найден"

with open('test.txt', 'w', encoding='utf-8') as f:
    f.write("""Первая строка текста
Вторая строка с большим количеством слов
Третья строка
Четвертая строка для теста
Пятая и последняя строка""")

print("Содержимое файла:")
with open('test.txt', 'r', encoding='utf-8') as f:
    print(f.read())
print()

stats = file_statistics('test.txt')
print("Статистика:")
for key, value in stats.items():
    print(f"{key}: {value}")

print("\nНесуществующий файл:")
print(file_statistics('no_file.txt'))
# Out:
# Содержимое файла:
# Первая строка текста
# Вторая строка с большим количеством слов
# Третья строка
# Четвертая строка для теста
# Пятая и последняя строка
#
# Статистика:
# lines: 5
# words: 19
# chars_with_spaces: 127
# chars_without_spaces: 113
#
# Несуществующий файл:
# Файл не найден

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №8. Поиск и замена в файле**

# %% [markdown]
# Напишите функцию `replace_in_file(filename, old_text, new_text)`, которая заменяет все вхождения `old_text` на `new_text` в файле и сохраняет результат в новый файл с префиксом "modified_".
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с текстом, содержащим минимум 3 вхождения заменяемого слова
# - Выведите содержимое файла ДО замены
# - Выполните замену
# - Выведите содержимое файла ПОСЛЕ замены
# - Покажите количество произведенных замен

# %%
def replace_in_file(filename, old_text, new_text):
    with open(filename, 'r') as f:
        content = f.read()

    modified_content = content.replace(old_text, new_text)
    count = content.count(old_text)
    new_filename = 'modified_' + filename

    with open(new_filename, 'w') as f:
        f.write(modified_content)
    return count, new_filename

with open('text.txt', 'w') as f:
    f.write('кошка играет с кошкой\n')
    f.write('у соседа есть кошка\n')
    f.write('кошка - домашнее животное\n')
    f.write('все кошки милые\n')

print("ДО замены:")
with open('text.txt') as f:
    print(f.read())
count, new_file = replace_in_file('text.txt', 'кошка', 'собака')

print("\nПОСЛЕ замены:")
with open(new_file) as f:
    print(f.read())
print(f"\nПроизведено замен: {count}")
# Out:
# ДО замены:
# кошка играет с кошкой
# у соседа есть кошка
# кошка - домашнее животное
# все кошки милые
#
#
# ПОСЛЕ замены:
# собака играет с кошкой
# у соседа есть собака
# собака - домашнее животное
# все кошки милые
#
#
# Произведено замен: 3

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №9. Объединение файлов**

# %% [markdown]
# Создайте функцию `merge_files(file_list, output_file)`, которая объединяет содержимое нескольких текстовых файлов в один, добавляя после каждого разделитель.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте минимум 3 файла с разным содержимым
# - Выведите содержимое КАЖДОГО исходного файла
# - Выполните объединение
# - Выведите содержимое результирующего файла

# %%
def merge_files(file_list, output_file):
    with open(output_file, 'w') as out:
        for filename in file_list:
            with open(filename) as f:
                out.write(f.read())
            out.write('\nРаботает, просто не сохраняется\n')

with open('file1.txt', 'w') as f:
    f.write('1')

with open('file2.txt', 'w') as f:
    f.write('2')

with open('file3.txt', 'w') as f:
    f.write('3')

files = ['file1.txt', 'file2.txt', 'file3.txt']
for file in files:
    with open(file) as f:
        print(f'Файл {file}: {f.read()}')

merge_files(files, 'result.txt')

with open('result.txt') as f:
    print('\nРезультат:\n' + f.read())
# Out:
# Файл file1.txt: 1
# Файл file2.txt: 2
# Файл file3.txt: 3
#
# Результат:
# 1
# Работает, просто не сохраняется
# 2
# Работает, просто не сохраняется
# 3
# Работает, просто не сохраняется

# %% [markdown]
# ---
